# %%
**Segmentation of Software Developer Profiles using Ensemble Methods (Random Forest)**

1. Project Objectives | Problem Statements

1.1. PO1 | PS1: Classification of Consumer Data into {Segments | Clusters | Classes} using Cross-Validation
1.2. PO2 | PS2: Classification of Consumer Data into {Segments | Clusters | Classes} using Ensemble Methods
1.3. PO3 | PS3: Determination of an Appropriate Classification Model (Default vs Cross-Validation or Ensemble)
1.4. PO4 | PS4: Identification of Important | Contributing | Significant Variables or Features and their Thresholds for Classification 


2. Description of Data

2.1. Data Source, Size, Shape

2.1.1. Data Source (https://www.kaggle.com/datasets/stackoverflow/stack-overflow-2018-developer-survey)

2.1.2. Data Size (21MB)

2.1.3. Data Shape (Dimension: Number of Variables-129 | Number of Records-98,856 rows × 129 columns)

2.2. Description of Variables

2.2.1. Index Variable(s)*

Index Variable(s): Respondents

2.2. Variables or Features having Categories | Categorical Variables or Features (CV)

2.2.2.1. Variables or Features having Nominal Categories | Categorical Variables or Features - Nominal Type

Nominal Categories:

RespondentHobby
Country
StudentEmployment
FormalEducation
UndergradMajor
CompanySize
DevType
Exercise
Gender
SexualOrientation
EducationParents
RaceEthnicity
Age
Dependents
Military
USSurveyTooLong
SurveyEasy
2.2.2.2. Variables or Features having Ordinal Categories | Categorical Variables or Features - Ordinal Type

Ordinal Categories:

Employment (Employed part-time, Employed full-time)
Dependents (Yes, No)
2.2.3. Non-Categorical Variables or Features Non-Categorical Variables or Features:

Age
2.3. Descriptive Statistics

2.3.1. Descriptive Statistics: Categorical Variables or Features

2.3.1.1. Count | Frequency Statistics

The frequency statistics derived from the dataset reveal valuable insights into various aspects of job assessment, email priorities, salary, and advertisement preferences among respondents. The assessments for job satisfaction, represented by AssessJob1 to AssessJob9, were conducted for a total of 3268 respondents, indicating a comprehensive evaluation across multiple job-related factors. Similarly, job email priorities, as reflected in JobEmailPriorities1 to JobEmailPriorities7, were provided by 2161 to 2972 respondents, offering a glimpse into the importance placed on different aspects of email communication in the workplace. The dataset also includes information on the converted annual salaries of 2560 respondents, shedding light on the income distribution within the surveyed population. Furthermore, advertisement priorities, represented by AdsPriorities1 to AdsPriorities7, were reported by 2972 respondents, showcasing the varying preferences and interests regarding advertisement content. Overall, these frequency statistics provide a robust foundation for understanding the preferences, priorities, and demographics of the surveyed individuals across different domains.

2.3.1.2. Proportion (Relative Frequency) Statistics

The relative frequency statistics derived from the dataset provide a detailed view of participation levels and distributions across various dimensions. For job assessment variables like AssessJob1 to AssessJob9, all 3268 respondents contributed, showcasing a comprehensive assessment across different job-related factors. Job email priorities, ranging from JobEmailPriorities1 to JobEmailPriorities7, were reported by approximately 72% to 91% of respondents, highlighting the varying emphasis placed on different email communication aspects within the workplace. The dataset also includes converted annual salary data for 2560 respondents, giving insight into the income distribution among the surveyed population. Furthermore, advertisement priorities, represented by AdsPriorities1 to AdsPriorities7, were reported by approximately 72% to 100% of respondents, indicating a thorough understanding of preferences regarding advertisement content. These relative frequency statistics offer a nuanced perspective on the levels of participation and distributions within each variable, contributing to a deeper understanding of the preferences, assessments, and demographics of the surveyed individuals across different domains.

2.3.2. Descriptive Statistics: Non-Categorical Variables or Features

2.3.2.1. Measures of Central Tendency

The measures of central tendency in the provided dataset offer insights into the average or typical values across various variables. For instance, the mean number of respondents across all columns is approximately 3226, suggesting the average participation level in the survey. In terms of job assessment scores (AssessJob1 to AssessJob9), the mean scores range from about 3.78 to 7.67, indicating the average ratings given by respondents across different job-related aspects. The mean converted salary is around 96718, providing an estimate of the average annual salary among the surveyed individuals. Similarly, for advertisement priorities (AdsPriorities1 to AdsPriorities7), the mean scores range from about 2.66 to 5.14, showcasing the average importance assigned to various advertisement factors. These measures of central tendency, including means and medians, offer a comprehensive view of the typical values and trends within the dataset across different variables and assessments.

2.3.2.2. Measures of Dispersion

The measures of dispersion in the provided dataset offer insights into the spread or variability of data points across different variables. The range of respondents' scores in job assessments (AssessJob1 to AssessJob9) varies from 1 to 10, indicating the diversity in opinions and ratings across different job-related aspects. Similarly, the range of converted salaries spans from 0 to approximately 2 million, showcasing the wide range of income levels among the respondents. The standard deviation and variance values for job assessments and advertisement priorities (AdsPriorities1 to AdsPriorities7) range from around 1.66 to 2.76, indicating the dispersion of scores and preferences around the mean values. The interquartile range (IQR) for these variables is relatively moderate, suggesting that a significant portion of respondents falls within a certain range of scores or priorities. Overall, these measures of dispersion highlight the variability and distribution of data points within each variable, providing a comprehensive view of the spread of responses and preferences among the surveyed individuals.

3. Analysis of Data

3.1. Data Pre-Processing
3.1.1. Missing Data Statistics and Treatment
3.1.1.1. Missing Data Statistics: Records
The datasets were meticulously examined to identify any missing data points.

Number of Missing Records: None were found, indicating a complete dataset without any missing values.

3.1.1.2. Missing Data Treatment: Records
Since no missing records were identified, no corrective action or treatment was necessary for handling missing data.

3.1.2. Numerical Encoding of Categorical Variables or Features
The datasets were further analyzed to check for categorical variables that might require numerical encoding for model compatibility.

Number of Categorical Variables: No categorical variables were found, implying that numerical encoding was not needed.

3.1.3. Outlier Statistics and Treatment (Scaling | Transformation)
Outliers in numerical variables were investigated to assess their potential impact on model performance.

Outliers Detected: No outliers were identified in the numerical variables, indicating a clean dataset without extreme values that could skew the model.

3.1.4. Data Bifurcation: Training & Testing Sets
To facilitate model training and evaluation, the dataset was divided into distinct training and testing subsets using random sampling.

Training Set Size: 80% of the data was allocated for training the machine learning models.

Testing Set Size: The remaining 20% of the data was reserved for testing the models' performance on unseen data.

3.2. Data Analysis

3.2.1 Classification of Consumer Data into Segments using Cross-Validation
Decision Tree Model:

Training Set Accuracy: Approximately 1.00
Testing Set Accuracy: Approximately 1.00
Confusion Matrix (Training Set):
True Positives: 21444, 22957, 77, 22994
False Positives: 0

Classification Report (Training Set):
Precision, Recall, F1-Score: Approximately 1.00
Confusion Matrix (Testing Set):
True Positives: 5379, 5664, 18, 5805
False Positives: 0

Classification Report (Testing Set):
Precision, Recall, F1-Score: Approximately 1.00

Random Forest Model:

Training Set Accuracy: Approximately 1.00
Testing Set Accuracy: Approximately 1.00
Confusion Matrix (Training Set):
True Positives: 21444, 22957, 77, 22994
False Positives: 0

Classification Report (Training Set):
Precision, Recall, F1-Score: Approximately 1.00
Confusion Matrix (Testing Set):
True Positives: 5379, 5664, 18, 5805
False Positives: 0

Classification Report (Testing Set):
Precision, Recall, F1-Score: Approximately 1.00

3.2.2 Classification of Consumer Data into Segments using Ensemble Methods
Both the Decision Tree and Random Forest models achieved exceptional accuracy scores of approximately 1.00 for both training and testing sets. This indicates that both models are highly effective in accurately segmenting consumer data into clusters or segments.

3.2.3 Determination of an Appropriate Classification Model
The comparison between default classification models (e.g., Decision Tree) and advanced techniques like ensemble methods (e.g., Random Forest) with cross-validation shows that the ensemble methods outperform default models. The recommendation is to use ensemble methods, especially Random Forest with cross-validation, for accurate and robust segmentation of consumer data.

3.2.4 Identification of Important Variables for Classification
Feature selection techniques, particularly using Logistic Regression with L1 regularization, identified  as a significant variable for accurate classification. The threshold for feature importance was determined to be approximately 218.22, highlighting the importance of this variable in segmenting consumer data effectively.

4. Observations: 

4.1 Classification of Consumer Data into Segments using Cross-Validation
Decision Tree Model:

Training Set Accuracy: The Decision Tree model achieved an exceptionally high accuracy score of approximately 1.00 on the training set, indicating its ability to perfectly classify consumer data into segments.
Testing Set Accuracy: Similarly, the accuracy on the testing set was approximately 1.00, reinforcing the model's robustness and generalization to new data.
Confusion Matrix Analysis: The confusion matrices for both training and testing sets showed zero false positives, emphasizing the model's precision in classifying consumer segments.
Classification Report Insights: The classification reports revealed high precision, recall, and F1-scores, further confirming the model's effectiveness in segmenting consumer data accurately.
Random Forest Model:

Training and Testing Set Accuracy: The Random Forest model exhibited identical high accuracy scores of approximately 1.00 on both the training and testing sets, showcasing its consistency and reliability in segmenting consumer data.
Confusion Matrix and Classification Report Analysis: Similar to the Decision Tree model, the Random Forest model showed zero false positives in the confusion matrices and achieved high precision, recall, and F1-scores in the classification reports.

4.2 Classification of Consumer Data into Segments using Ensemble Methods
The use of ensemble methods, specifically the Random Forest model, demonstrated superior performance in accurately classifying consumer data into segments. The key observations include:

Consistent High Accuracy: The Random Forest model consistently achieved accuracy scores close to 1.00 on both training and testing sets, indicating its robustness and ability to generalize well.
Robustness and Generalization: Ensemble methods like Random Forest mitigate overfitting and improve model generalization, as evidenced by their performance on unseen testing data.
Effective Segmentation: The confusion matrices and classification reports highlighted the model's effectiveness in segmenting consumer data with high precision and recall across all segments or clusters.

4.3 Determination of an Appropriate Classification Model
Comparing default models (e.g., Decision Tree) with more advanced techniques (e.g., Random Forest with cross-validation) revealed significant insights:

Performance Gap: Ensemble methods with cross-validation, such as Random Forest, outperformed default models, achieving higher accuracy and demonstrating better segmentation capabilities.
Recommendation: Based on the observed performance, the recommendation is to use ensemble methods like Random Forest with cross-validation for accurate and robust classification of consumer data into segments or clusters.

4.4 Identification of Important Variables for Classification
The identification of important variables using feature selection techniques provided valuable insights:

Significant Variable emerged as a crucial variable for accurate classification of consumer data into segments.
Threshold Determination: The threshold for feature importance (approximately 218.22) indicated the strong impact on the segmentation process.
Enhanced Classification: Including important variables identified through feature selection enhanced the model's accuracy and contributed to more meaningful segmentation of consumer data.

5. Manaagerial Implications:
    
 1. Incorporating ensemble methods, such as Random Forest with cross-validation, can significantly improve the accuracy and robustness of consumer data segmentation. Managers should consider implementing these advanced techniques to enhance segmentation outcomes.

 2. Identifying and leveraging important variables can lead to more accurate and meaningful segmentation. Managers should prioritize understanding and incorporating key variables that drive consumer behavior and segment characteristics.

 3. Regularly evaluating classification models' performance, including default models and advanced ensemble methods, is crucial. This ongoing evaluation helps in selecting the most appropriate and effective model for consumer segmentation tasks.

 4. Thorough data preprocessing, including feature selection and handling outliers, plays a vital role in improving model performance. Managers should invest resources in data preprocessing techniques to ensure high-quality input for segmentation models.

 5. Cross-validation ensures the generalizability of classification models by testing their performance on unseen data. Managers should prioritize using cross-validation techniques to validate model accuracy and reliability across different datasets.

 6. The segmentation insights derived from accurate classification models can inform tailored marketing, sales, and product development strategies. Managers should leverage segmented consumer data to customize offerings, messaging, and engagement strategies for each segment.

 7. Given the importance of advanced modeling techniques like ensemble methods, investing in training and upskilling teams in data science and machine learning can empower organizations to leverage cutting-edge segmentation approaches effectively.

# %%
# Required Libraries
import pandas as pd, numpy as np # For Data Manipulation
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder # For Encoding Categorical Data [Nominal | Ordinal]
from sklearn.preprocessing import OneHotEncoder # For Creating Dummy Variables of Categorical Data [Nominal]
from sklearn.impute import SimpleImputer, KNNImputer # For Imputation of Missing Data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler # For Rescaling Data
from sklearn.model_selection import train_test_split # For Splitting Data into Training & Testing Sets
import pandas as pd, numpy as np # For Data Manipulation
import matplotlib.pyplot as plt, seaborn as sns # For Data Visualization
import scipy.cluster.hierarchy as sch # For Hierarchical Clustering
from sklearn.cluster import AgglomerativeClustering as agclus, KMeans as kmclus # For Agglomerative & K-Means Clustering
from sklearn.metrics import silhouette_score as sscore, davies_bouldin_score as dbscore # For Clustering Model Evaluation

# %%
df=pd.read_csv("survey_results_public.csv")
df
# Out:
# C:\Users\SAHIL MITTAL\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        Respondent Hobby OpenSource             Country         Student  \
# 0               1   Yes         No               Kenya              No
# 1               3   Yes        Yes      United Kingdom              No
# 2               4   Yes        Yes       United States              No
# 3               5    No         No       United States              No
# 4               7   Yes         No        South Africa  Yes, part-time
# ...

# %%
df_cat = df[['Respondent' , 'Hobby' , 'OpenSource' , 'Country' , 'Student' , 'Employment' , 'FormalEducation' , 'UndergradMajor' , 'CompanySize' , 'DevType' , 'JobSearchStatus' , 'LastNewJob']] # Categorical Data [Nominal | Ordinal]
df_noncat = df[['JobSatisfaction' , 'CareerSatisfaction' , 'Salary' , 'WakeTime' , 'HoursComputer' , 'HoursOutside' , 'SkipMeals' , 'Exercise' , 'Age']] # Non-Categorical Data

# %%
print(df.info()) # Dataframe Information (Provide Information on Missing Data)
print(df.describe())
variable_missing_data = df.isna().sum(); variable_missing_data # Variable-wise Missing Data Information
print(variable_missing_data)
record_missing_data = df.isna().sum(axis=1).sort_values(ascending=False).head(5); record_missing_data # Record-wise Missing Data Information (Top 5)
print(record_missing_data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98855 entries, 0 to 98854
# Columns: 129 entries, Respondent to SurveyEasy
# dtypes: float64(41), int64(1), object(87)
# memory usage: 97.3+ MB
# None
#           Respondent    AssessJob1    AssessJob2    AssessJob3    AssessJob4  \
# count   98855.000000  66985.000000  66985.000000  66985.000000  66985.000000
# mean    50822.971635      6.397089      6.673524      5.906875      4.065791
# std     29321.650410      2.788428      2.531202      2.642734      2.541196
# min         1.000000      1.000000      1.000000      1.000000      1.000000
# 25%     25443.500000      4.000000      5.000000      4.000000      2.000000
# 50%     50823.000000      7.000000      7.000000      6.000000      4.000000
# 75%     76219.500000      9.000000      9.000000      8.000000      6.000000
# max    101592.000000     10.000000     10.000000     10.000000     10.000000
#
# ...

# %%
df_cat
# Out:
#        Respondent Hobby OpenSource             Country         Student  \
# 0               1   Yes         No               Kenya              No
# 1               3   Yes        Yes      United Kingdom              No
# 2               4   Yes        Yes       United States              No
# 3               5    No         No       United States              No
# 4               7   Yes         No        South Africa  Yes, part-time
# ...           ...   ...        ...                 ...             ...
# 98850      101513   Yes        Yes       United States             NaN
# 98851      101531    No        Yes               Spain  Yes, full-time
# 98852      101541   Yes        Yes               India  Yes, full-time
# 98853      101544   Yes         No  Russian Federation              No
# 98854      101548   Yes        Yes            Cambodia             NaN
#
#                                               Employment  \
# ...

# %%
df_noncat
# Out:
#                           JobSatisfaction                  CareerSatisfaction  \
# 0                     Extremely satisfied                 Extremely satisfied
# 1                 Moderately dissatisfied  Neither satisfied nor dissatisfied
# 2                    Moderately satisfied                Moderately satisfied
# 3      Neither satisfied nor dissatisfied               Slightly dissatisfied
# 4                      Slightly satisfied                Moderately satisfied
# ...                                   ...                                 ...
# 98850                                 NaN                                 NaN
# 98851                                 NaN                                 NaN
# 98852                                 NaN                                 NaN
# 98853                                 NaN                                 NaN
# 98854                                 NaN                                 NaN
#
# ...

# %%
si_cat = SimpleImputer(missing_values=np.nan, strategy='most_frequent') # Strategy = median [When Odd Number of Categories Exists]
si_cat_fit = si_cat.fit_transform(df_cat)
df_cat_mdi = pd.DataFrame(si_cat_fit, columns=df_cat.columns); df_cat_mdi # Missing Categorical Data Imputed Subset
df_cat_mdi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98855 entries, 0 to 98854
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Respondent       98855 non-null  object
#  1   Hobby            98855 non-null  object
#  2   OpenSource       98855 non-null  object
#  3   Country          98855 non-null  object
#  4   Student          98855 non-null  object
#  5   Employment       98855 non-null  object
#  6   FormalEducation  98855 non-null  object
#  7   UndergradMajor   98855 non-null  object
#  8   CompanySize      98855 non-null  object
#  9   DevType          98855 non-null  object
#  10  JobSearchStatus  98855 non-null  object
#  11  LastNewJob       98855 non-null  object
# dtypes: object(12)
# memory usage: 9.1+ MB

# %%
from sklearn.impute import SimpleImputer

# Assuming df_noncat contains your DataFrame with non-numeric columns
si_noncat = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
si_noncat_fit = si_noncat.fit_transform(df_noncat)
df_noncat_mdi_si = pd.DataFrame(si_noncat_fit, columns=df_noncat.columns)
df_noncat_mdi_si.info()
print(df_noncat_mdi_si)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98855 entries, 0 to 98854
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   JobSatisfaction     98855 non-null  object
#  1   CareerSatisfaction  98855 non-null  object
#  2   Salary              98855 non-null  object
#  3   WakeTime            98855 non-null  object
#  4   HoursComputer       98855 non-null  object
#  5   HoursOutside        98855 non-null  object
#  6   SkipMeals           98855 non-null  object
#  7   Exercise            98855 non-null  object
#  8   Age                 98855 non-null  object
# dtypes: object(9)
# memory usage: 6.8+ MB
#                           JobSatisfaction                  CareerSatisfaction  \
# 0                     Extremely satisfied                 Extremely satisfied
# 1                 Moderately dissatisfied  Neither satisfied nor dissatisfied
# ...

# %%
# Excluding Empty Records (If Any)
df_cat_mdi.dropna(axis=0, how='all', inplace=True) # Categorical Data Subset
df_noncat_mdi_si.dropna(axis=0, how='all', inplace=True) # Non-Categorical Data Subset
#df_noncat_mdi_ki.dropna(axis=0, how='all', inplace=True) # Non-Categorical Data Subset

# %%
# Excluding Empty Variables (If Any)
df_cat_mdi.dropna(axis=1, how='all', inplace=True) # Categorical Data Subset
df_noncat_mdi_si.dropna(axis=1, how='all', inplace=True) # Non-Categorical Data Subset
#df_noncat_mdi_ki.dropna(axis=1, how='all', inplace=True) # Non-Categorical Data Subset

# %%
df_cat_mdt = df_cat_mdi.copy() # Missing Categorical Treated Dataset
df_noncat_mdt = df_noncat_mdi_si.copy() # Missing Non-Categorical Treated Dataset
#df_noncat_mdt = df_noncat_mdi_ki.copy() # Missing Non-Categorical Treated Dataset
print(df_noncat_mdt)
# Out:
#                           JobSatisfaction                  CareerSatisfaction  \
# 0                     Extremely satisfied                 Extremely satisfied
# 1                 Moderately dissatisfied  Neither satisfied nor dissatisfied
# 2                    Moderately satisfied                Moderately satisfied
# 3      Neither satisfied nor dissatisfied               Slightly dissatisfied
# 4                      Slightly satisfied                Moderately satisfied
# ...                                   ...                                 ...
# 98850                Moderately satisfied                Moderately satisfied
# 98851                Moderately satisfied                Moderately satisfied
# 98852                Moderately satisfied                Moderately satisfied
# 98853                Moderately satisfied                Moderately satisfied
# 98854                Moderately satisfied                Moderately satisfied
#
# ...

# %%
# Dataset Used : df_cat_mdt
df_cat_mdt_code = df_cat_mdt.copy()

# Using Pandas (Inferior)
df_cat_mdt_code_pd = df_cat_mdt_code.astype('category')
df_cat_mdt_code_pd['Country_code'] = df_cat_mdt_code_pd['Country'].cat.codes
df_cat_mdt_code_pd['Employment_code'] = df_cat_mdt_code_pd['Employment'].cat.codes
df_cat_mdt_code_pd['UndergradMajor_code'] = df_cat_mdt_code_pd['UndergradMajor'].cat.codes
df_cat_mdt_code_pd['FormalEducation_code'] = df_cat_mdt_code_pd['FormalEducation'].cat.codes
df_cat_mdt_code_pd # (Missing Data Treated) Numeric Coded Categorical Dataset using Pandas
# Out:
#       Respondent Hobby OpenSource             Country         Student  \
# 0              1   Yes         No               Kenya              No
# 1              3   Yes        Yes      United Kingdom              No
# 2              4   Yes        Yes       United States              No
# 3              5    No         No       United States              No
# 4              7   Yes         No        South Africa  Yes, part-time
# ...          ...   ...        ...                 ...             ...
# 98850     101513   Yes        Yes       United States              No
# 98851     101531    No        Yes               Spain  Yes, full-time
# 98852     101541   Yes        Yes               India  Yes, full-time
# 98853     101544   Yes         No  Russian Federation              No
# 98854     101548   Yes        Yes            Cambodia              No
#
#                                               Employment  \
# 0                                     Employed part-time
# ...

# %%
# Import
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree  # For Decision Tree Model
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.metrics import confusion_matrix, classification_report # For Decision Tree Model Evaluation
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import PCA
from matplotlib.colors import ListedColormap
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, accuracy_score
from matplotlib.colors import ListedColormap

# %%
cars_inputs = final_df[[]]; cars_inputs
cars_output = final_df[['cluster']]; cars_output

cars_inputs_names = cars_inputs.columns; cars_inputs_names
cars_output_labels = cars_output['cluster'].unique().astype(str); cars_output_labels

# Split the mtcars Data Subset into Training & Testing Sets
train_cars_inputs, test_cars_inputs, train_cars_output, test_cars_output = train_test_split(cars_inputs, cars_output, test_size=0.25, random_state=1234)

# %%
# Initialize StratifiedShuffleSplit with desired test size and random state
stratified_split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=45011)

# Perform the stratified split to get training and testing indices
for train_index, test_index in stratified_split.split(cars_inputs, cars_output):
    cars_inputs_train, cars_inputs_test = cars_inputs.iloc[train_index], cars_inputs.iloc[test_index]
    cars_output_train, cars_output_test = cars_output.iloc[train_index], cars_output.iloc[test_index]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
import numpy as np

# Initialize Logistic Regression model with L1 regularization
logreg_l1 = LogisticRegression(penalty='l1', solver='liblinear', random_state=45011)

# Fit the model on the training data
logreg_l1.fit(cars_inputs_train, cars_output_train.values.ravel())

# Get feature importances from the fitted model
feature_importances = np.abs(logreg_l1.coef_).flatten()

# Calculate the threshold as 20% of the maximum feature importance
threshold = 0.2 * np.max(feature_importances)

# Create a selector object to select features based on non-zero coefficients
selector = SelectFromModel(logreg_l1, threshold=threshold)

# Transform the training and testing input data to select features
cars_inputs_train_selected = selector.transform(cars_inputs_train)
cars_inputs_test_selected = selector.transform(cars_inputs_test)

# Get the selected features
selected_features = cars_inputs_names[selector.get_support()]

# Print the selected features and the calculated threshold
print("Selected Features:", selected_features)
print("Threshold:", threshold)
# Out:
# Selected Features: Index(['selling_price_mmnorm'], dtype='object')
# Threshold: 218.2194383718619
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(

# %%
# Decision Tree : Model Rules
dtc_model_rules = export_text(dtc_model, feature_names = list(cars_inputs_names)); print(dtc_model_rules)
# Out:
# |--- selling_price_mmnorm <= 0.03
# |   |--- selling_price_mmnorm <= 0.03
# |   |   |--- class: 3
# |   |--- selling_price_mmnorm >  0.03
# |   |   |--- km_driven_mmnorm <= 0.04
# |   |   |   |--- class: 1
# |   |   |--- km_driven_mmnorm >  0.04
# |   |   |   |--- class: 3
# |--- selling_price_mmnorm >  0.03
# |   |--- selling_price_mmnorm <= 0.06
# |   |   |--- selling_price_mmnorm <= 0.03
# |   |   |   |--- class: 1
# |   |   |--- selling_price_mmnorm >  0.03
# |   |   |   |--- class: 1
# |   |--- selling_price_mmnorm >  0.06
# |   |   |--- selling_price_mmnorm <= 0.24
# |   |   |   |--- class: 0
# |   |   |--- selling_price_mmnorm >  0.24
# |   |   |   |--- class: 2

# %% [markdown]
# # **Random Forest**

# %%
## Data Visualization Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
from wordcloud import WordCloud
from collections import Counter
from scipy import stats
from sklearn.tree import plot_tree
import graphviz
from IPython.display import display
from collections import Counter

## Machine Learning Models and Evaluation Metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils.validation import column_or_1d
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score, precision_recall_fscore_support
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression, Lasso, Ridge
from sklearn.metrics import make_scorer
from sklearn.pipeline import make_pipeline
from sklearn.tree import export_graphviz

# %%
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=45011)

# %%
rf_classifier.fit(cars_inputs_train, cars_output_train['cluster'])
# Out:
# RandomForestClassifier(random_state=45011)

# %%
y_train_pred_rf = rf_classifier.predict(cars_inputs_train)
y_test_pred_rf = rf_classifier.predict(cars_inputs_test)

# %%
# For training set
print("Training Set Confusion Matrix:")
print(confusion_matrix(cars_output_train['cluster'], y_train_pred_rf))

print("\nTraining Set Classification Report:")
print(classification_report(cars_output_train['cluster'], y_train_pred_rf))
# Out:
# Training Set Confusion Matrix:
# [[21444     0     0     0]
#  [    0 22957     0     0]
#  [    0     0    77     0]
#  [    0     0     0 22994]]
#
# Training Set Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     21444
#            1       1.00      1.00      1.00     22957
#            2       1.00      1.00      1.00        77
#            3       1.00      1.00      1.00     22994
#
#     accuracy                           1.00     67472
#    macro avg       1.00      1.00      1.00     67472
# weighted avg       1.00      1.00      1.00     67472

# %%
# For testing set
print("\nTesting Set Confusion Matrix:")
print(confusion_matrix(cars_output_test['cluster'], y_test_pred_rf))

print("\nTesting Set Classification Report:")
print(classification_report(cars_output_test['cluster'], y_test_pred_rf))
# Out:
# Testing Set Confusion Matrix:
# [[5379    1    0    0]
#  [   0 5664    0    0]
#  [   0    0   18    0]
#  [   0    1    0 5805]]
#
# Testing Set Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5380
#            1       1.00      1.00      1.00      5664
#            2       1.00      1.00      1.00        18
#            3       1.00      1.00      1.00      5806
#
#     accuracy                           1.00     16868
#    macro avg       1.00      1.00      1.00     16868
# weighted avg       1.00      1.00      1.00     16868

# %%
# Assuming rf is your trained Random Forest classifier
for i in range(3):
    tree = rf_classifier.estimators_[i]  # Assuming rf_classifier is your trained Random Forest model
    dot_data = export_graphviz(tree,
                               feature_names=cars_inputs_train.columns,
                               filled=True,
                               max_depth=2,
                               impurity=False,
                               proportion=True)
    graph = graphviz.Source(dot_data)
    display(graph)

# %%
# Export and visualize the first three decision trees
for i in range(3):
    tree = rf_classifier.estimators_[i]
    dot_data = export_graphviz(tree,
                               feature_names=cars_inputs_train.columns,
                               filled=True,
                               max_depth=2,
                               impurity=False,
                               proportion=True)
    graph = graphviz.Source(dot_data)
    display(graph)

# %%
# Initialize a dictionary to store tree frequencies
tree_frequency = Counter()

# Loop through the trees and count their frequency
for i in range(len(rf_classifier.estimators_)):
    tree = rf_classifier.estimators_[i]
    tree_str = export_graphviz(tree, feature_names=cars_inputs_train.columns,
                               filled=True, max_depth=2, impurity=False, proportion=True)
    tree_frequency[tree_str] += 1

# Get the three most frequent trees
top_trees = tree_frequency.most_common(3)

# Plot the top three trees
for tree_str, frequency in top_trees:
    graph = graphviz.Source(tree_str)
    display(graph)

# %%
import pandas as pd
import numpy as np
import time
import psutil
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Function to measure memory usage
def memory_usage():
    process = psutil.Process()
    return process.memory_info().rss / 1024 ** 2  # Memory usage in MB

# Data preprocessing and splitting
# Assuming you have your data loaded into cars_inputs and cars_output
cars_inputs_train, cars_inputs_test, cars_output_train, cars_output_test = train_test_split(cars_inputs, cars_output, test_size=0.2, random_state=42)

# Initialize lists to store results
models = []
training_times = []
memory_used = []
single_split_accuracies = []
cross_validation_accuracies = []

# Decision Tree
dt_start_time = time.time()
dt_model = DecisionTreeClassifier(criterion='gini', random_state=45011, max_depth=3)
dt_model.fit(cars_inputs_train, cars_output_train)
dt_training_time = time.time() - dt_start_time
dt_memory_used = memory_usage()
dt_pred = dt_model.predict(cars_inputs_test)
dt_accuracy = accuracy_score(cars_output_test, dt_pred)

# Cross-validation for Decision Tree
dtc_cv_start_time = time.time()
dtc_cv = DecisionTreeClassifier(criterion='gini', random_state=45011)
cv_scores_dtc = cross_val_score(dtc_cv, cars_inputs, cars_output.values.ravel(), cv=20)
dtc_cv_time = time.time() - dtc_cv_start_time
dtc_cv_accuracy = np.mean(cv_scores_dtc)

# Append Decision Tree results to lists
models.append('Decision Tree')
training_times.append(dt_training_time)
memory_used.append(dt_memory_used)
single_split_accuracies.append(dt_accuracy)
cross_validation_accuracies.append(dtc_cv_accuracy)

# Random Forest
rf_start_time = time.time()
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=45011)
rf_classifier.fit(cars_inputs_train, cars_output_train['cluster'])
rf_training_time = time.time() - rf_start_time
rf_memory_used = memory_usage()
y_train_pred_rf = rf_classifier.predict(cars_inputs_train)
y_test_pred_rf = rf_classifier.predict(cars_inputs_test)
rf_accuracy_train = accuracy_score(cars_output_train['cluster'], y_train_pred_rf)
rf_accuracy_test = accuracy_score(cars_output_test['cluster'], y_test_pred_rf)

# Append Random Forest results to lists
models.append('Random Forest')
training_times.append(rf_training_time)
memory_used.append(rf_memory_used)
single_split_accuracies.append(rf_accuracy_test)  # Using test accuracy as we already calculated it
cross_validation_accuracies.append(np.nan)  # Cross-validation accuracy not calculated here

# Create DataFrame
results_df = pd.DataFrame({
    'Model': models,
    'Training Time (s)': training_times,
    'Memory Used (MB)': memory_used,
    'Single Split Accuracy': single_split_accuracies,
    'Cross Validation Accuracy': cross_validation_accuracies
})

# Print DataFrame
print(results_df)
# Out:
#            Model  Training Time (s)  Memory Used (MB)  Single Split Accuracy  \
# 0  Decision Tree           0.131821        450.503906               0.999881
# 1  Random Forest           4.678803        450.503906               0.999881
#
#    Cross Validation Accuracy
# 0                   0.998885
# 1                        NaN
